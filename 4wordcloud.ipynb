# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from wordcloud import WordCloud

# %%
df = pd.read_csv('anime.csv')
df.head(20)
# Out:
#     anime_id                                 title   type  score  scored_by  \
# 0       5114      Fullmetal Alchemist: Brotherhood     tv   9.13    1871705
# 1      11061                Hunter x Hunter (2011)     tv   9.04    1509622
# 2      38524    Shingeki no Kyojin Season 3 Part 2     tv   9.07    1329500
# 3       9253                           Steins;Gate     tv   9.08    1252286
# 4      28851                        Koe no Katachi  movie   8.95    1398608
# 5      32281                        Kimi no Na wa.  movie   8.86    1675677
# 6       2904    Code Geass: Hangyaku no Lelouch R2     tv   8.91    1079799
# 7      40028  Shingeki no Kyojin: The Final Season     tv   8.83    1080165
# 8        199         Sen to Chihiro no Kamikakushi  movie   8.78    1149660
# 9       1575       Code Geass: Hangyaku no Lelouch     tv   8.70    1266726
# 10      1535                            Death Note     tv   8.62    2451294
# 11     40748                   Jujutsu Kaisen (TV)     tv   8.68    1249570
# 12     23273               Shigatsu wa Kimi no Uso     tv   8.66    1207643
# 13     35760           Shingeki no Kyojin Season 3     tv   8.62    1366582
# 14        21                             One Piece     tv   8.66    1095305
# 15         1                          Cowboy Bebop     tv   8.76     844830
# 16     16498                    Shingeki no Kyojin     tv   8.53    2484450
# 17     38000                      Kimetsu no Yaiba     tv   8.54    1732637
# 18     37510                     Mob Psycho 100 II     tv   8.81     794061
# 19     30276                         One Punch Man     tv   8.51    1989312
#
#               status  episodes  start_date    end_date        source  ...  \
# 0    finished_airing      64.0  2009-04-05  2010-07-04         manga  ...
# 1    finished_airing     148.0  2011-10-02  2014-09-24         manga  ...
# 2    finished_airing      10.0  2019-04-29  2019-07-01         manga  ...
# 3    finished_airing      24.0  2011-04-06  2011-09-14  visual_novel  ...
# 4    finished_airing       1.0  2016-09-17  2016-09-17         manga  ...
# 5    finished_airing       1.0  2016-08-26  2016-08-26      original  ...
# 6    finished_airing      25.0  2008-04-06  2008-09-28      original  ...
# 7    finished_airing      16.0  2020-12-07  2021-03-29         manga  ...
# 8    finished_airing       1.0  2001-07-20  2001-07-20      original  ...
# 9    finished_airing      25.0  2006-10-06  2007-07-29      original  ...
# 10   finished_airing      37.0  2006-10-04  2007-06-27         manga  ...
# 11   finished_airing      24.0  2020-10-03  2021-03-27         manga  ...
# 12   finished_airing      22.0  2014-10-10  2015-03-20         manga  ...
# 13   finished_airing      12.0  2018-07-23  2018-10-15         manga  ...
# 14  currently_airing       NaN  1999-10-20         NaN         manga  ...
# 15   finished_airing      26.0  1998-04-03  1999-04-24      original  ...
# 16   finished_airing      25.0  2013-04-07  2013-09-29         manga  ...
# 17   finished_airing      26.0  2019-04-06  2019-09-28         manga  ...
# 18   finished_airing      13.0  2019-01-07  2019-04-01     web_manga  ...
# 19   finished_airing      12.0  2015-10-05  2015-12-21     web_manga  ...
#
#                                             producers  \
# 0   ['Aniplex', 'Square Enix', 'Mainichi Broadcast...
# 1    ['VAP', 'Nippon Television Network', 'Shueisha']
# 2   ['Production I.G', 'Dentsu', 'Mainichi Broadca...
# 3   ['Frontier Works', 'Media Factory', 'Movic', '...
# 4   ['Shochiku', 'Pony Canyon', 'Kodansha', 'ABC A...
# 5   ['Toho', 'Sound Team Don Juan', 'Amuse', 'JR E...
# 6   ['Bandai Visual', 'Mainichi Broadcasting Syste...
# 7   ['Production I.G', 'Dentsu', 'Mainichi Broadca...
# 8                                            ['Toho']
# 9   ['Bandai Visual', 'Mainichi Broadcasting Syste...
# 10  ['VAP', 'Konami', 'Ashi Production', 'Nippon T...
# 11  ['Mainichi Broadcasting System', 'TOHO animati...
# 12  ['Aniplex', 'Dentsu', 'Kodansha', 'Fuji TV', '...
# 13  ['Production I.G', 'Dentsu', 'Mainichi Broadca...
# 14                     ['Fuji TV', 'TAP', 'Shueisha']
# 15                                  ['Bandai Visual']
# 16  ['Production I.G', 'Dentsu', 'Mainichi Broadca...
# 17                            ['Aniplex', 'Shueisha']
# 18  ['Warner Bros. Japan', 'KlockWorx', 'BS Fuji',...
# 19  ['TV Tokyo', 'Bandai Visual', 'Lantis', 'Asats...
#
#                                     licensors  \
# 0        ['Funimation', 'Aniplex of America']
# 1                               ['VIZ Media']
# 2                              ['Funimation']
# 3                              ['Funimation']
# 4                ['Eleven Arts', 'NYAV Post']
# 5                 ['Funimation', 'NYAV Post']
# 6      ['Funimation', 'Bandai Entertainment']
# 7                              ['Funimation']
# 8   ['Disney Platform Distribution', 'GKIDS']
# 9      ['Funimation', 'Bandai Entertainment']
# 10                              ['VIZ Media']
# 11                                         []
# 12                     ['Aniplex of America']
# 13                             ['Funimation']
# 14      ['Funimation', '4Kids Entertainment']
# 15     ['Funimation', 'Bandai Entertainment']
# 16                             ['Funimation']
# 17                     ['Aniplex of America']
# 18                             ['Funimation']
# 19                              ['VIZ Media']
#
#                                              synopsis  \
# 0   After a horrific alchemy experiment goes wrong...
# 1   Hunters devote themselves to accomplishing haz...
# 2   Seeking to restore humanity's diminishing hope...
# 3   Eccentric scientist Rintarou Okabe has a never...
# 4   As a wild youth, elementary school student Sho...
# 5   Mitsuha Miyamizu, a high school girl, yearns t...
# 6   One year has passed since the Black Rebellion,...
# 7   Gabi Braun and Falco Grice have been training ...
# 8   Stubborn, spoiled, and naïve, 10-year-old Chih...
# 9   In the year 2010, the Holy Empire of Britannia...
# 10  Brutal murders, petty thefts, and senseless vi...
# 11  Idly indulging in baseless paranormal activiti...
# 12  Kousei Arima is a child prodigy known as the "...
# 13  Still threatened by the "Titans" that rob them...
# 14  Gol D. Roger was known as the "Pirate King," t...
# 15  Crime is timeless. By the year 2071, humanity ...
# 16  Centuries ago, mankind was slaughtered to near...
# 17  Ever since the death of his father, the burden...
# 18  Shigeo "Mob" Kageyama is now maturing and unde...
# 19  The seemingly unimpressive Saitama has a rathe...
#
#                                            background  \
# 0                                                 NaN
# 1                                                 NaN
# 2   Shingeki no Kyojin adapts content from volumes...
# 3   Steins;Gate is based on 5pb. and Nitroplus' re...
# 4   Winner of the Excellence Award on the 20th Jap...
# 5   Kimi no Na wa. won the LAFCA Animation Award i...
# 6   Code Geass: Hangyaku no Lelouch R2 is an origi...
# 7                                                 NaN
# 8   Sen to Chihiro no Kamikakushi held the record ...
# 9   Code Geass: Hangyaku no Lelouch is an original...
# 10  Death Note has been adapted into live action f...
# 11  Winner of the Anime of the Year (TV Series) at...
# 12  Winner in the anime division of the 2016 Sugoi...
# 13  Shingeki no Kyojin adapts content from volumes...
# 14  Several anime-original arcs have been adapted ...
# 15  When Cowboy Bebop first aired in spring of 199...
# 16  Shingeki no Kyojin adapts content from the fir...
# 15  https://www.youtube.com/watch?v=qig4KOK2R2g
# 16  https://www.youtube.com/watch?v=LHtdKWJdif4
# 17  https://www.youtube.com/watch?v=6vMuWuWlW4I
# 18  https://www.youtube.com/watch?v=Pr43Sayk37s
# 19  https://www.youtube.com/watch?v=ExUMiF1L0HA
#
#                               title_english              title_japanese  \
# 0          Fullmetal Alchemist: Brotherhood  鋼の錬金術師 FULLMETAL ALCHEMIST
# 1                           Hunter x Hunter    HUNTER×HUNTER（ハンター×ハンター）
# 2           Attack on Titan Season 3 Part 2        進撃の巨人 Season3 Part.2
# 3                               Steins;Gate                 STEINS;GATE
# 4                            A Silent Voice                         聲の形
# 5                                Your Name.                       君の名は。
# 6   Code Geass: Lelouch of the Rebellion R2          コードギアス 反逆のルルーシュ 続編
# 7         Attack on Titan: The Final Season      進撃の巨人 The Final Season
# 8                             Spirited Away                    千と千尋の神隠し
# 9      Code Geass: Lelouch of the Rebellion             コードギアス 反逆のルルーシュ
# 10                               Death Note                       デスノート
# 11                           Jujutsu Kaisen                        呪術廻戦
# 12                        Your Lie in April                      四月は君の嘘
# 13                 Attack on Titan Season 3               進撃の巨人 Season3
# 14                                One Piece                   ONE PIECE
# 15                             Cowboy Bebop                   カウボーイビバップ
# 16                          Attack on Titan                       進撃の巨人
# 17           Demon Slayer: Kimetsu no Yaiba                        鬼滅の刃
# 18                        Mob Psycho 100 II                 モブサイコ100 II
# 19                            One Punch Man                      ワンパンマン
#
#                                        title_synonyms
# 0   ['Hagane no Renkinjutsushi: Fullmetal Alchemis...
# 1                                      ['HxH (2011)']
# 2                                                  []
# 3                                                  []
# 4                              ['The Shape of Voice']
# 5                                                  []
# 6   ['Code Geass: Hangyaku no Lelouch 2nd Season',...
# 7   ['Shingeki no Kyojin Season 4', 'Attack on Tit...
# 8                ["Sen and Chihiro's Spiriting Away"]
# 9                                                  []
# 10                                             ['DN']
# 11                           ['Sorcery Fight', 'JJK']
# 12                                        ['Kimiuso']
# 13                                                 []
# 14                                             ['OP']
# 15                                                 []
# 16                                     ['AoT', 'SnK']
# 17                     ['Blade of Demon Destruction']
# 18  ['Mob Psycho 100 2nd Season', 'Mob Psycho Hyak...
# 19          ['One Punch-Man', 'One-Punch Man', 'OPM']
#
# [20 rows x 39 columns]

# %%
df.isna().sum()
# Out:
# anime_id                0
# title                   0
# type                   73
# score                9893
# scored_by               0
# status                  0
# episodes              768
# start_date           2774
# end_date             4253
# source               3761
# members                 0
# favorites               0
# episode_duration      863
# total_duration       1163
# rating               1017
# sfw                     0
# approved                0
# created_at              0
# updated_at              0
# start_year           6416
# start_season         6416
# real_start_date      2774
# real_end_date        4253
# broadcast_day       21100
# broadcast_time      21237
# genres                  0
# themes                  0
# demographics            0
# studios                 0
# producers               0
# licensors               0
# synopsis             3317
# background          21823
# main_picture         2787
# url                     0
# trailer_url         19803
# title_english       15081
# title_japanese        254
# title_synonyms          0
# dtype: int64

# %%
new_df = df[df['episodes'].notnull()]
new_df = new_df[ df['score'] >= 8.5]
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_6864\3498370855.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   new_df = new_df[ df['score'] >= 8.5]

# %%
text = " ".join(title for title in new_df.title).lower()

# %%
word_cloud = WordCloud(collocations = True, background_color = 'white').generate(text)

plt.imshow(word_cloud, interpolation='bilinear')
plt.axis("off")
plt.show()
